# %%
import pandas as pd
import numpy as np
import os

data = pd.read_csv("Toyotacleaneddata.csv")
# data.info()

data["Age"].median()
data['Age'] = data['Age'].fillna(data['Age'].median())

data['KM'].mean()
data['KM'] = data['KM'].fillna(data['KM'].mean())

data.describe()
data.isna().sum()
data['MetColor'].value_counts()
# Out:
# MetColor
# 1.0    868
# 0.0    418
# Name: count, dtype: int64
