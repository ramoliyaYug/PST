# %%
import pandas as pd
data = {
    "id" : ['s01','s02','s03','s04','s05'],
    "student" : ["yug","ananya","anvita","annu","shivika"],
    "rank" : [2,3,4,5,1],
    "marks" : [90,70,60,50,45]
}

dataframe = pd.DataFrame(data)
print(dataframe)

#insert new column
dataframe.insert(2,"Roll",[101,102,103,104,105])
print(dataframe)

#use assign method
dataframe.assign(School =["abc","def","ghi","jkl","mno"])
print(dataframe)

# %%
# drop() takes in two parameters- the name of the row/column you want to remove
# + the axis

# Deleting columns using the drop() method.
import pandas as pd

data1 ={
    'Id': ['S01', 'S02', 'S03', 'S04', 'S05'],
    'Student': ['Steve', 'John', 'Jacob', 'David', 'Steve'],
    'Rank': [1, 4, 3, 5, 2],
    'Marks': [95, 70, 80, 60, 90]
}
dataframe1 = pd.DataFrame(data1, index = ["Index0","Index1","Index2","Index3","Index4"])
print(dataframe1)

resultframe = dataframe1.drop("Marks", axis = "columns")
print("\n\n",resultframe)

resultframe1 = dataframe1.drop("Marks", axis = 1)
print("\n\n",resultframe1)

# Deleting rows using drop() method
resultframe2 = dataframe1.drop("Index2", axis = "index")
print("\n\n",resultframe2)

resultframe3 = dataframe1.drop("Index2", axis = 0)
print("\n\n",resultframe3)
# Out:
#          Id Student  Rank  Marks
# Index0  S01   Steve     1     95
# Index1  S02    John     4     70
# Index2  S03   Jacob     3     80
# Index3  S04   David     5     60
# Index4  S05   Steve     2     90
#
#
#           Id Student  Rank
# Index0  S01   Steve     1
# Index1  S02    John     4
# Index2  S03   Jacob     3
# Index3  S04   David     5
# Index4  S05   Steve     2
#
#
#           Id Student  Rank
# Index0  S01   Steve     1
# Index1  S02    John     4
# Index2  S03   Jacob     3
# Index3  S04   David     5
# Index4  S05   Steve     2
#
#
#           Id Student  Rank  Marks
# Index0  S01   Steve     1     95
# Index1  S02    John     4     70
# Index3  S04   David     5     60
# Index4  S05   Steve     2     90
#
#
#           Id Student  Rank  Marks
# Index0  S01   Steve     1     95
# Index1  S02    John     4     70
# Index3  S04   David     5     60
# Index4  S05   Steve     2     90

# %%
import pandas as pd

data1 ={
    'Id': ['S01', 'S02', 'S03', 'S04', 'S05'],
    'Student': ['Steve', 'John', 'Jacob', 'David', 'Steve'],
    'Rank': [1, 4, 3, 5, 2],
    'Marks': [95, 70, 80, 60, 90]
}
dataframe1 = pd.DataFrame(data1, index = ["Index0","Index1","Index2","Index3","Index4"])
print(dataframe1)

print("sorting" + "\n")
print(dataframe1.sort_values(by = "Marks", ascending = False))
# Out:
#          Id Student  Rank  Marks
# Index0  S01   Steve     1     95
# Index1  S02    John     4     70
# Index2  S03   Jacob     3     80
# Index3  S04   David     5     60
# Index4  S05   Steve     2     90
# sorting
#
#          Id Student  Rank  Marks
# Index0  S01   Steve     1     95
# Index4  S05   Steve     2     90
# Index2  S03   Jacob     3     80
# Index1  S02    John     4     70
# Index3  S04   David     5     60
